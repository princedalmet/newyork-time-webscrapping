# %% [markdown]
# <a href="https://colab.research.google.com/github/princetondalmet/newyork-time-webscrapping/blob/main/newyork%20times.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import bs4 as bs
import urllib.request

# %%
src = urllib.request.urlopen('https://www.nytimes.com/').read()

# %%
bsoup = bs.BeautifulSoup(src, 'lxml')

# %%
print(bsoup)
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <meta charset="utf-8"/>
# <title data-rh="true">The New York Times - Breaking News, US News, World News and Videos</title>
# ...

# %%
print(bsoup.title.text)
# Out:
# The New York Times - Breaking News, US News, World News and Videos

# %%
for link in bsoup.find_all('a'):
    print(link.get('href'))
# Out:
# #site-content
# #site-index
# /
# /
# /international/?action=click&region=Editions&pgtype=Homepage
# /ca/?action=click&region=Editions&pgtype=Homepage
# https://www.nytimes.com/es/
# https://cn.nytimes.com
# https://myaccount.nytimes.com/auth/login?response_type=cookie&client_id=vi&redirect_uri=https%3A%2F%2Fwww.nytimes.com%2Fsubscription%2Fmultiproduct%2Flp8KQUS.html%3FcampaignId%3D7JFJX&asset=masthead
# https://www.nytimes.com/section/todayspaper
# https://myaccount.nytimes.com/auth/login?response_type=cookie&client_id=vi&redirect_uri=https%3A%2F%2Fwww.nytimes.com%2Fsubscription%2Fmultiproduct%2Flp8KQUS.html%3FcampaignId%3D7JFJX&asset=masthead
# /
# /
# /section/world
# /section/us
# /section/politics
# /section/nyregion
# /section/business
# /section/opinion
# /section/technology
# /section/science
# /section/health
# /section/sports
# /section/arts
# /section/books
# /section/style
# /section/food
# /section/travel
# /section/magazine
# /section/t-magazine
# /section/realestate
# ...

# %%
print(bsoup.p)
# Out:
# <p class="summary-class css-1azn4ub">American and European officials say their concern is based in part on a growing conviction that the war will not end any time soon.</p>

# %%
print(bsoup.find_all('p'))
# Out:
# [<p class="summary-class css-1azn4ub">American and European officials say their concern is based in part on a growing conviction that the war will not end any time soon.</p>, <p class="summary-class css-1azn4ub">Economic growth in the first three months of the year may mask the strength of the American recovery.</p>, <p class="summary-class css-1azn4ub">Since the Great Recession, the college-educated have taken more frontline jobs at companies like Starbucks and Amazon. Now they’re helping to unionize them.</p>, <p class="summary-class css-1azn4ub">The company has also requested authorization of its Covid vaccine for 6- to 11-year-olds and 12- to 17-year-olds. Here’s the latest pandemic news.</p>, <p class="summary-class css-1azn4ub">The Republican senator is leaning into her centrist credentials and bipartisan ties in her re-election race, hoping that voters will reward moderation.</p>, <p class="summary-class css-1azn4ub">As union members maintain their affections for former Presid
# ...

# %%
print(bsoup.find('p').get_text())
# Out:
# American and European officials say their concern is based in part on a growing conviction that the war will not end any time soon.

# %%
ptags = bsoup.find_all('p')
for p in ptags:
    print(p.text)
# Out:
# American and European officials say their concern is based in part on a growing conviction that the war will not end any time soon.
# Economic growth in the first three months of the year may mask the strength of the American recovery.
# Since the Great Recession, the college-educated have taken more frontline jobs at companies like Starbucks and Amazon. Now they’re helping to unionize them.
# The company has also requested authorization of its Covid vaccine for 6- to 11-year-olds and 12- to 17-year-olds. Here’s the latest pandemic news.
# The Republican senator is leaning into her centrist credentials and bipartisan ties in her re-election race, hoping that voters will reward moderation.
# As union members maintain their affections for former President Trump, Democrats like Representative Marcy Kaptur find their base of support eroding quickly.
# ...

# %%
src = urllib.request.urlopen('http://www.espn.com/nba/statistics/player/_/stat/assists/sort/avgAssists/').read()
bsoup = bs.BeautifulSoup(src, 'lxml')
tbl = bsoup.find('table')

# %%
tbl_rows = tbl.find_all('tr')
for tr in tbl_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    print(row)
# Out:
# []
# ['-', 'Luka DoncicDAL']
# ['1', 'Nikola JokicDEN']
# ['2', 'Jimmy ButlerMIA']
# ['3', 'Jayson TatumBOS']
# ['4', 'Giannis AntetokounmpoMIL']
# ['4', 'Jalen BrunsonDAL']
# ['6', 'Brandon IngramNO']
# ['7', 'Stephen CurryGS']
# ['-', 'Devin BookerPHX']
# ['8', 'Kevin DurantBKN']
# ['9', 'Donovan MitchellUTAH']
# ['10', 'Joel EmbiidPHI']
# ['11', 'Anthony EdwardsMIN']
# ['12', 'Desmond BaneMEM']
# ['13', 'CJ McCollumNO']
# ['14', 'Klay ThompsonGS']
# ['14', 'Karl-Anthony TownsMIN']
# ['14', 'Pascal SiakamTOR']
# ['-', 'Jaylen BrownBOS']
# ['17', 'Ja MorantMEM']
# ['-', 'Kyrie IrvingBKN']
# ['18', "De'Andre HunterATL"]
# ['19', 'Jordan PooleGS']
# ['20', 'DeMar DeRozanCHI']
# ['21', 'Tyrese MaxeyPHI']
# ['22', 'Chris PaulPHX']
# ['22', 'Deandre AytonPHX']
# ['-', 'OG AnunobyTOR']
# ['-', 'Nikola VucevicCHI']
# ['-', 'Zach LaVineCHI']
# ['-', 'James HardenPHI']
# ['-', 'Jordan ClarksonUTAH']
# ['-', 'Bojan BogdanovicUTAH']
# ['-', 'Tobias HarrisPHI']
# ['-', 'Mikal BridgesPHX']
# ...

# %%
type(row)
# Out:
# list

# %%
import pandas as pd 
data = pd.read_html("http://www.espn.com/nba/statistics/player/_/stat/assists/sort/avgAssists/")
for df in data:
    print(df)
# Out:
#     RK                      Name
# 0    -            Luka DoncicDAL
# 1    1           Nikola JokicDEN
# 2    2           Jimmy ButlerMIA
# 3    3           Jayson TatumBOS
# 4    4  Giannis AntetokounmpoMIL
# 5    4          Jalen BrunsonDAL
# 6    6          Brandon IngramNO
# 7    7           Stephen CurryGS
# 8    -           Devin BookerPHX
# 9    8           Kevin DurantBKN
# 10   9      Donovan MitchellUTAH
# 11  10            Joel EmbiidPHI
# 12  11        Anthony EdwardsMIN
# 13  12           Desmond BaneMEM
# 14  13             CJ McCollumNO
# 15  14           Klay ThompsonGS
# 16  14     Karl-Anthony TownsMIN
# 17  14          Pascal SiakamTOR
# 18   -           Jaylen BrownBOS
# 19  17              Ja MorantMEM
# 20   -           Kyrie IrvingBKN
# 21  18        De'Andre HunterATL
# 22  19            Jordan PooleGS
# 23  20          DeMar DeRozanCHI
# 24  21           Tyrese MaxeyPHI
# 25  22             Chris PaulPHX
# 26  22          Deandre AytonPHX
# ...
